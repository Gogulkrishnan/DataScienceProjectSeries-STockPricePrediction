# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LinearRegression

# %%
df_stock= pd.read_csv(r"F:\PROJECTS\StockPricePrediction\data\archive.zip")

# %%
df_stock.head()
# Out:
#          date       open       high        low      close   adjclose  volume  \
# 0  2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000  106600
# 1  2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000  128700
# 2  2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001  103100
# 3  2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000  173600
# 4  2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000  137800
#
#   ticker  RSIadjclose15  RSIvolume15  ...  high-15  K-15  D-15  \
# 0   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 1   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 2   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 3   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 4   ASLE            NaN          NaN  ...      NaN   NaN   NaN
#
#    stochastic-k-15  stochastic-d-15  stochastic-kd-15  volumenrelativo  \
# ...

# %%
df_stock.shape
# Out:
# (7781, 1285)

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Columns: 1285 entries, date to TARGET
# dtypes: float64(1280), int64(3), object(2)
# memory usage: 76.3+ MB

# %%
df_stock.describe()
# Out:
# c:\Users\GOGUL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\GOGUL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\GOGUL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\GOGUL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\GOGUL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
# ...

# %%
df_stock.isnull().sum()
# Out:
# date                  0
# open                  0
# high                  0
# low                   0
# close                 0
#                    ...
# stochastic-kd-15    587
# volumenrelativo     215
# diff                155
# INCREMENTO          155
# TARGET                0
# Length: 1285, dtype: int64

# %%
data_new = df_stock[['date','open', 'high', 'low', 'close']]
data_new
# Out:
#             date       open       high        low      close
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000
# ...          ...        ...        ...        ...        ...
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001
# 7777  2022-12-27  23.350000  23.610001  23.250000  23.350000
# 7778  2022-12-28  23.450001  23.570000  23.219999  23.350000
# 7779  2022-12-29  23.330000  23.740000  23.330000  23.610001
# 7780  2022-12-30  23.680000  23.760000  23.610001  23.610001
#
# [7781 rows x 5 columns]

# %%
data_new.isnull().sum()
# Out:
# date     0
# open     0
# high     0
# low      0
# close    0
# dtype: int64

# %%
data_new["tomorrow"]= data_new["close"].shift(-1)
data_new
# Out:
# C:\Users\GOGUL\AppData\Local\Temp\ipykernel_2532\3575239668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new["tomorrow"]= data_new["close"].shift(-1)
#             date       open       high        low      close   tomorrow
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.660000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  16.950001
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.170000
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  15.710000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.860000
# ...          ...        ...        ...        ...        ...        ...
# ...

# %%
data_new["target"] = data_new["tomorrow"] > data_new["close"].astype(float)
data_new
# Out:
# C:\Users\GOGUL\AppData\Local\Temp\ipykernel_2532\1825596126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new["target"] = data_new["tomorrow"] > data_new["close"].astype(float)
#             date       open       high        low      close   tomorrow  \
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.660000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  16.950001
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.170000
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  15.710000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.860000
# ...          ...        ...        ...        ...        ...        ...
# ...

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      7781 non-null   object
#  1   open      7781 non-null   float64
#  2   high      7781 non-null   float64
#  3   low       7781 non-null   float64
#  4   close     7781 non-null   float64
#  5   tomorrow  7780 non-null   float64
#  6   target    7781 non-null   bool
# dtypes: bool(1), float64(5), object(1)
# memory usage: 372.5+ KB

# %%
import pandas as pd

# Convert the 'date' column to datetime
data_new['date'] = pd.to_datetime(data_new['date'])

# Convert the datetime to Unix timestamp (in seconds)
data_new['date'] = data_new['date'].astype('int64') // 10**9
# Out:
# C:\Users\GOGUL\AppData\Local\Temp\ipykernel_2532\1605141294.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new['date'] = pd.to_datetime(data_new['date'])
# C:\Users\GOGUL\AppData\Local\Temp\ipykernel_2532\1605141294.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new['date'] = data_new['date'].astype('int64') // 10**9

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split= 100, random_state=1)

# %%
X = data_new.drop('target',axis=1)
y = data_new['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(min_samples_split=100, n_estimators=200, random_state=1)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
print(f"\nAccuracy: {accuracy:.2f}")
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.73
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.70      0.89      0.79      1323
#         True       0.78      0.51      0.62      1012
#
#     accuracy                           0.73      2335
#    macro avg       0.74      0.70      0.70      2335
# weighted avg       0.74      0.73      0.71      2335

# %%
regr = LinearRegression()

# %%
data_new['tomorrow']
# Out:
# 0       17.660000
# 1       16.950001
# 2       16.170000
# 3       15.710000
# 4       15.860000
#           ...
# 7776    23.350000
# 7777    23.350000
# 7778    23.610001
# 7779    23.610001
# 7780          NaN
# Name: tomorrow, Length: 7781, dtype: float64

# %%
data_new.loc[7780, 'tomorrow'] = 23.610001
data_new['tomorrow']
# Out:
# 0       17.660000
# 1       16.950001
# 2       16.170000
# 3       15.710000
# 4       15.860000
#           ...
# 7776    23.350000
# 7777    23.350000
# 7778    23.610001
# 7779    23.610001
# 7780    23.610001
# Name: tomorrow, Length: 7781, dtype: float64

# %%
linear_X = data_new.drop('target',axis=1)
linear_y = data_new['target']

# %%
linear_X_train, linear_X_test, linear_y_train, linear_y_test = train_test_split(linear_X, linear_y, train_size=0.8, random_state=42)

# %%
regr.fit(linear_X_train,linear_y_train)
# Out:
# LinearRegression()

# %%
linear_y_pred = regr.predict(linear_X_test)

# %%
# Convert probabilities to binary predictions
linear_y_pred = [1 if pred >= 0.5 else 0 for pred in linear_y_pred]

linear_accuracy = accuracy_score(linear_y_test, linear_y_pred)
linear_classification_rep = classification_report(linear_y_test, linear_y_pred)

# %%
print(f"\nAccuracy: {linear_accuracy:.2f}")
print("\nClassification Report:\n", linear_classification_rep)
# Out:
# Accuracy: 0.58
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.58      1.00      0.73       880
#         True       0.91      0.04      0.08       677
#
#     accuracy                           0.58      1557
#    macro avg       0.74      0.52      0.41      1557
# weighted avg       0.72      0.58      0.45      1557

# %%
#from the observations randomforestclassifier model gives better acccuracy and precision
